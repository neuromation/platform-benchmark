# %% [markdown]
# # Predict analysis

# %%
# %load_ext autoreload
# %autoreload 2

import notebook_utils as u
from pathlib import Path


path_to_ckpt = Path('/var/results/last.ckpt')
path_to_data = Path('/var/data/test')

# %%
u.compute_and_show_conf_mat(test_dir=path_to_data,
                          path_to_ckpt=path_to_ckpt)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 24.86it/s]
